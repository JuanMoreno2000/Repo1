py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# Generación de histograma usando matplotlib.

# %%
import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(x=vals, bins=30)
plt.title('Histograma de tiempos de servicio')
plt.xlabel('Tiempos de servicio')
plt.ylabel('Frecuencia')
plt.show()

print(bins)
print(count)
# Out:
# [1.45465323 1.55210419 1.64955514 1.74700609 1.84445705 1.941908
#  2.03935896 2.13680991 2.23426086 2.33171182 2.42916277 2.52661372
#  2.62406468 2.72151563 2.81896658 2.91641754 3.01386849 3.11131945
#  3.2087704  3.30622135 3.40367231 3.50112326 3.59857421 3.69602517
#  3.79347612 3.89092708 3.98837803 4.08582898 4.18327994 4.28073089
#  4.37818184]
# [ 2.  1.  1.  8. 11. 12. 10. 16. 33. 37. 40. 61. 67. 56. 74. 69. 78. 70.
#  70. 75. 44. 48. 40. 16. 14. 19.  8.  9.  7.  4.]

# %% [markdown]
# Densidad normal estándar.

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

# Normal (mu=0, sigma=1)
x= np.arange(-4,4,0.001)
plt.plot(x, norm.pdf(x))
plt.title('Función de densidad normal estándar')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()

# %% [markdown]
# Densidad normal con media 3 y desviación estándar 1.

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

# Normal (mu=3, sigma=1)
x= np.arange(0,6,0.001)
plt.plot(x, norm.pdf(x,loc=3))
plt.title('Función de densidad normal(mu=3, sigma=1)')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()

# %% [markdown]
# Densidad normal con media 3 y desviación estándar 0.5.

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

# Normal (mu=0, sigma=1)
x= np.arange(0,6,0.001)
plt.plot(x, norm.pdf(x,loc=3,scale=0.5))
plt.title('Función de densidad normal(mu=3, sigma=0.5)')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()

# %% [markdown]
# QQ plot usando statsmodels.

# %%
import statsmodels.api as sm
import scipy.stats as stats
fig = sm.qqplot(data = vals, dist=stats.norm, loc=3, scale=0.5, line="45")
plt.show()

# %% [markdown]
# QQ plot contra normal con media 3 y desviación estándar 1.

# %%
import statsmodels.api as sm
import scipy.stats as stats
fig = sm.qqplot(data = vals, dist=stats.norm, loc=3, scale=1, line="45")
plt.show()

# %% [markdown]
# QQ plot contra normal con media 0 y desviación estándar 1.

# %%
import statsmodels.api as sm
import scipy.stats as stats
fig = sm.qqplot(data = vals, dist=stats.norm, loc=0, scale=1, line="45")
plt.show()

# %%
import matplotlib.pyplot as plt
# histograma
count, bins, ignored = plt.hist(x=vals, bins=30, density=True)

# densidad normal(3, 0.5)
x= np.arange(1,5,0.001)
plt.plot(x, norm.pdf(x,loc=3,scale=0.5))

plt.title('Tiempos de servicio')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.stats import expon

lambdad = 0.5
n = 50000
valores = np.random.exponential(scale=1/lambdad, size=n)

# histograma
count, bins, ignored = plt.hist(x=valores, bins=30, density=True)

# densidad exponencial
x= np.arange(0,15,0.01)
plt.plot(x, expon.pdf(x,scale=1/lambdad))

plt.title('Cantidad de tiempo')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()
